# %%
from bs4 import BeautifulSoup as bs
import requests
import re
import json
import pandas as pd

# %%
page_text = open('/Users/ex10si0n/Desktop/url2.html', 'r')
page_text = page_text.read()
page_text = page_text.replace('&gt;', '>').replace('&lt;', '<')
soup = bs(page_text, 'lxml')

# %%
article = soup.find('tbody', {'class': 'ant-table-tbody'})
tr = article.find_all('tr')
for t in tr:
    t = str(t)
    
    e = t.find('"><td class="ant-tab')
    s = t.find('data-row-key')
    
    print(s)
    print(t[72:100])
    print('-' * 50)
# Out:
# "><td style="padding: 0px; b
# -1
# -1
# --------------------------------------------------
# 40300141"><td class="ant-tab
# 80
# 58
# --------------------------------------------------
# 188888880"><td class="ant-ta
# 81
# 58
# --------------------------------------------------
# 50204684"><td class="ant-tab
# 80
# 58
# --------------------------------------------------
# 917792206"><td class="ant-ta
# 81
# 58
# --------------------------------------------------
# 23848974"><td class="ant-tab
# 80
# 58
# --------------------------------------------------
# 1096637401"><td class="ant-t
# 82
# 58
# --------------------------------------------------
# 59241800"><td class="ant-tab
# 80
# 58
# --------------------------------------------------
# 103432682"><td class="ant-ta
# 81
# 58
# --------------------------------------------------
# 74405960"><td class="ant-tab
# 80
# 58
# --------------------------------------------------
# 1472313264"><td class="ant-t
# 82
# 58
# ...
